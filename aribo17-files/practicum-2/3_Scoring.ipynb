# %% [markdown]
# # Implementing a custom retrieval method based on term statistics from Elasticsearch
#
#   1. Implement the TF-IDF weighting formula by completing the `score()` method.
#
#   2. Implement Language Modeling (query (log)likelihood) scoring as a new `score_lm()` method.
#
#   3. Implement BM25 scoring as a new `score_bm25()` method.
#
#
# We use documents by taking the dot product of query and document term weights: $score(q,d)=\sum_{t \in q}w_{t,q} w_{t,d}$.
# Different retrieval models can be instantiated by setting these weights as follows:
#
# | Retrieval Model | $w_{t,q}$ | $w_{t,d}$ |
# | -- | -- | -- |
# | TF-IDF | $f_{t,q}$ | $\frac{f_{t,d}}{|d|} IDF_t$ |
# | LM | $f_{t,q}$ | $\log \Big( (1-\lambda) \frac{f_{t,d}}{|d|} + \lambda \frac{f_{t,C}}{cl} \Big)$ |
# | BM25 | $f_{t,q}$ | $\frac{f_{t,d} (1+k_1)}{f_{t,d} + k_1(1-b+b\frac{|d|}{avgdl})} \times IDF_t$ |
#
#  - $f_{t,q}$ is the frequency of term t in query q
#  - $f_{t,d}$ is the frequency of term t in document d
#  - $f_{t,C}$ is the frequency of term t in the entire collection
#  - $IDF_{t}=\log \frac{N}{df_t}$
#  - $N$ is the total number of documents in the collection
#  - $df_t$ is the number of documents that contain term t
#  - $|d|$ is the length of document d
#  - $cl$ collection length (sum of all document lengths $\sum_{d'}|d|$)
#  - $\lambda$ is a smoothing parameter

# %%
from elasticsearch import Elasticsearch
import pprint

# %%
INDEX_NAME = "aquaint"
DOC_TYPE = "doc"
FIELD = "content"

# %% [markdown]
# ## Scoring method
#
# This is our "custom" scoring method.
#   - `es` is an Elasticsearch object; this is needed for getting term statistics from Elasticsearch.
#   - `qterms` holds a sequence of query terms. It is important that these terms must be analyzed the same way documents were analyzed during indexing.
#   - `doc_id` is the document's ID.
#
# The scoring method computes the dot product between the query term weights and document term weights: $score(q,d)=\sum_{t \in q}w_{t,q} w_{t,d}$.

# %%
def score(es, qterms, doc_id):
    # Total number of documents in the index
    n = es.count(index=INDEX_NAME, doc_type=DOC_TYPE)["count"]

    # Getting term frequency statistics for the given document field from Elasticsearch
    tv = es.termvectors(index=INDEX_NAME, doc_type=DOC_TYPE, id=doc_id, fields=[FIELD],
                              term_statistics=True).get("term_vectors", {}).get(FIELD, {})
    
    # uncomment to see what information ES returns
    pprint.pprint(tv)
        
    dl = sum([s["term_freq"] for t, s in tv["terms"].items()])  # length of the document
    cl = tv["field_statistics"]["sum_ttf"]  # collection length (total number of terms in a given field in all documents)
    avg_dl = cl / n
    
    print(avg_dl)
    
    s = 0  # holds the retrieval score
    for t in qterms:
        df_t = tv["terms"][t]["doc_freq"]  # number of docs in the collection that contain that term
        f_td = tv["terms"][t]["term_freq"]  # raw frequenct of t in d (number of times term t appears in doc d)
        t_tC = tv["terms"][t]["ttf"]  # frequency of t in the entire collection
        
        # TODO: setting query and document term weights
        w_tq = 1
        w_td = 1
        s += w_tq * w_td
    return s

# %% [markdown]
# ## Query analyzer
#
# See [indices.analyze](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.client.IndicesClient.analyze).

# %%
def analyze_query(es, query):
    tokens = es.indices.analyze(index=INDEX_NAME, body={"text": query})["tokens"]
    query_terms = []
    for t in sorted(tokens, key=lambda x: x["position"]):
        query_terms.append(t["token"])
    return query_terms

# %% [markdown]
# ## Main

# %%
es = Elasticsearch()

# %%
query = "tropical storms"

# %% [markdown]
# ### Retrieve the top-1 document using Elasticsearch
#
# We search a single field (set in `FIELD`).

# %%
res = es.search(index=INDEX_NAME, q=query, df=FIELD, _source=False, size=1).get("hits", {})

# %% [markdown]
# Get the ID of the first hit.

# %%
doc_id = res["hits"][0]["_id"]
print(doc_id)
# Out:
# APW19990810.0014

# %% [markdown]
# ### Re-score this document using our own retrieval method.

# %% [markdown]
# First, we need to transform the query string into a sequence of query terms, using the same analysis procedure that was used for building the index.

# %%
qterms = analyze_query(es, query)
print(qterms)
# Out:
# ['tropical', 'storms']

# %% [markdown]
# Then, we compute the "custom" retrieval score for this document.

# %%
new_score = score(es, qterms, doc_id)
# Out:
# {'field_statistics': {'doc_count': 1092710,
#                       'sum_doc_freq': 248972796,
#                       'sum_ttf': 482892167},
#  'terms': {'1': {'doc_freq': 241721,
#                  'term_freq': 1,
#                  'tokens': [{'end_offset': 891,
#                              'position': 133,
#                              'start_offset': 890}],
#                  'ttf': 678080},
#            '1.5': {'doc_freq': 15713,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 572,
#                                'position': 86,
#                                'start_offset': 569}],
#                    'ttf': 17073},
#            '111': {'doc_freq': 3765,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1662,
#                                'position': 259,
#                                'start_offset': 1659}],
#                    'ttf': 4396},
#            '14': {'doc_freq': 105171,
#                   'term_freq': 2,
#                   'tokens': [{'end_offset': 400,
#                               'position': 58,
#                               'start_offset': 398},
#                              {'end_offset': 1496,
#                               'position': 231,
#                               'start_offset': 1494}],
#                   'ttf': 162962},
#            '30': {'doc_freq': 161845,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 902,
#                               'position': 136,
#                               'start_offset': 900}],
#                   'ttf': 228643},
#            '39': {'doc_freq': 21535,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 1866,
#                               'position': 298,
#                               'start_offset': 1864}],
#                   'ttf': 27765},
#            '40': {'doc_freq': 83832,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 1718,
#                               'position': 272,
#                               'start_offset': 1716}],
#                   'ttf': 100624},
#            '54': {'doc_freq': 18625,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 1591,
#                               'position': 246,
#                               'start_offset': 1589}],
#                   'ttf': 24155},
#            '73': {'doc_freq': 10229,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 1872,
#                               'position': 300,
#                               'start_offset': 1870}],
#                   'ttf': 16158},
#            '74': {'doc_freq': 9646,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 1944,
#                               'position': 312,
#                               'start_offset': 1942}],
#                   'ttf': 13376},
#            'a': {'doc_freq': 976974,
#                  'term_freq': 11,
#                  'tokens': [{'end_offset': 456,
#                              'position': 66,
#                              'start_offset': 455},
#                             {'end_offset': 629,
#                              'position': 95,
#                              'start_offset': 628},
#                             {'end_offset': 705,
#                              'position': 109,
#                              'start_offset': 704},
#                             {'end_offset': 741,
#                              'position': 115,
#                              'start_offset': 740},
#                             {'end_offset': 1187,
#                              'position': 182,
#                              'start_offset': 1186},
#                             {'end_offset': 1468,
#                              'position': 227,
#                              'start_offset': 1467},
#                             {'end_offset': 1588,
#                              'position': 245,
#                              'start_offset': 1587},
#                             {'end_offset': 1715,
#                              'position': 271,
#                              'start_offset': 1714},
#                             {'end_offset': 1831,
#                              'position': 292,
#                              'start_offset': 1830},
#                             {'end_offset': 1879,
#                              'position': 302,
#                              'start_offset': 1878},
#                             {'end_offset': 1904,
#                              'position': 306,
#                              'start_offset': 1903}],
#                  'ttf': 10761691},
#            'about': {'doc_freq': 452537,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 148,
#                                  'position': 21,
#                                  'start_offset': 143}],
#                      'ttf': 1040347},
#            'across': {'doc_freq': 79747,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 1209,
#                                   'position': 186,
#                                   'start_offset': 1203},
#                                  {'end_offset': 1269,
#                                   'position': 195,
#                                   'start_offset': 1263}],
#                       'ttf': 98337},
#            "administration's": {'doc_freq': 7715,
#                                 'term_freq': 1,
#                                 'tokens': [{'end_offset': 817,
#                                             'position': 123,
#                                             'start_offset': 801}],
#                                 'ttf': 9339},
#            'air': {'doc_freq': 88933,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1253,
#                                'position': 193,
#                                'start_offset': 1250}],
#                    'ttf': 161075},
#            'along': {'doc_freq': 94665,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 308,
#                                  'position': 44,
#                                  'start_offset': 303}],
#                      'ttf': 117095},
#            'among': {'doc_freq': 153274,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1164,
#                                  'position': 178,
#                                  'start_offset': 1159}],
#                      'ttf': 198659},
#            'an': {'doc_freq': 642194,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 557,
#                               'position': 83,
#                               'start_offset': 555}],
#                   'ttf': 1674022},
#            'and': {'doc_freq': 1000653,
#                    'term_freq': 8,
#                    'tokens': [{'end_offset': 285,
#                                'position': 41,
#                                'start_offset': 282},
#                               {'end_offset': 321,
#                                'position': 47,
#                                'start_offset': 318},
#                               {'end_offset': 554,
#                                'position': 82,
#                                'start_offset': 551},
#                               {'end_offset': 788,
#                                'position': 121,
#                                'start_offset': 785},
#                               {'end_offset': 1235,
#                                'position': 190,
#                                'start_offset': 1232},
#                               {'end_offset': 1301,
#                                'position': 200,
#                                'start_offset': 1298},
#                               {'end_offset': 1539,
#                                'position': 237,
#                                'start_offset': 1536},
#                               {'end_offset': 1713,
#                                'position': 270,
#                                'start_offset': 1710}],
#                    'ttf': 11035062},
#            'ap': {'doc_freq': 239256,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 16,
#                               'position': 1,
#                               'start_offset': 14}],
#                   'ttf': 314237},
#            'are': {'doc_freq': 624300,
#                    'term_freq': 5,
#                    'tokens': [{'end_offset': 177,
#                                'position': 25,
#                                'start_offset': 174},
#                               {'end_offset': 271,
#                                'position': 39,
#                                'start_offset': 268},
#                               {'end_offset': 543,
#                                'position': 80,
#                                'start_offset': 540},
#                               {'end_offset': 1185,
#                                'position': 181,
#                                'start_offset': 1182},
#                               {'end_offset': 1333,
#                                'position': 205,
#                                'start_offset': 1330}],
#                    'ttf': 1861563},
#            'arlene': {'doc_freq': 465,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 1817,
#                                   'position': 289,
#                                   'start_offset': 1811}],
#                       'ttf': 596},
#            'at': {'doc_freq': 766019,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 767,
#                               'position': 118,
#                               'start_offset': 765}],
#                   'ttf': 2691259},
#            'atlantic': {'doc_freq': 19890,
#                         'term_freq': 3,
#                         'tokens': [{'end_offset': 260,
#                                     'position': 37,
#                                     'start_offset': 252},
#                                    {'end_offset': 1231,
#                                     'position': 189,
#                                     'start_offset': 1223},
#                                    {'end_offset': 1291,
#                                     'position': 198,
#                                     'start_offset': 1283}],
#                         'ttf': 28231},
#            'atmospheric': {'doc_freq': 1776,
#                            'term_freq': 2,
#                            'tokens': [{'end_offset': 800,
#                                        'position': 122,
#                                        'start_offset': 789},
#                                       {'end_offset': 1069,
#                                        'position': 166,
#                                        'start_offset': 1058}],
#                            'ttf': 2119},
#            'august': {'doc_freq': 82882,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 960,
#                                   'position': 146,
#                                   'start_offset': 954},
#                                  {'end_offset': 998,
#                                   'position': 153,
#                                   'start_offset': 992}],
#                       'ttf': 99083},
#            'average': {'doc_freq': 64933,
#                        'term_freq': 2,
#                        'tokens': [{'end_offset': 565,
#                                    'position': 84,
#                                    'start_offset': 558},
#                                   {'end_offset': 1249,
#                                    'position': 192,
#                                    'start_offset': 1242}],
#                        'ttf': 93292},
#            'be': {'doc_freq': 649295,
#                   'term_freq': 3,
#                   'tokens': [{'end_offset': 40,
#                               'position': 4,
#                               'start_offset': 38},
#                              {'end_offset': 703,
#                               'position': 108,
#                               'start_offset': 701},
#                              {'end_offset': 1045,
#                               'position': 162,
#                               'start_offset': 1043}],
#                   'ttf': 2012070},
#            'because': {'doc_freq': 273772,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 611,
#                                    'position': 91,
#                                    'start_offset': 604}],
#                        'ttf': 453046},
#            'becomes': {'doc_freq': 20281,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1902,
#                                    'position': 305,
#                                    'start_offset': 1895}],
#                        'ttf': 22779},
#            'been': {'doc_freq': 474366,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1790,
#                                 'position': 285,
#                                 'start_offset': 1786}],
#                     'ttf': 969046},
#            'begin': {'doc_freq': 52858,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 157,
#                                  'position': 23,
#                                  'start_offset': 152}],
#                      'ttf': 63706},
#            'bell': {'doc_freq': 12904,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 738,
#                                 'position': 114,
#                                 'start_offset': 734}],
#                     'ttf': 25741},
#            'below': {'doc_freq': 30660,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1241,
#                                  'position': 191,
#                                  'start_offset': 1236}],
#                      'ttf': 35470},
#            'busy': {'doc_freq': 13651,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1050,
#                                 'position': 163,
#                                 'start_offset': 1046}],
#                     'ttf': 14768},
#            'but': {'doc_freq': 554328,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 907,
#                                'position': 137,
#                                'start_offset': 904}],
#                    'ttf': 1812649},
#            'by': {'doc_freq': 797572,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 50,
#                               'position': 6,
#                               'start_offset': 48}],
#                   'ttf': 2840154},
#            'caribbean': {'doc_freq': 8339,
#                          'term_freq': 1,
#                          'tokens': [{'end_offset': 1311,
#                                      'position': 201,
#                                      'start_offset': 1302}],
#                          'ttf': 13184},
#            'carries': {'doc_freq': 10375,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1854,
#                                    'position': 295,
#                                    'start_offset': 1847}],
#                        'ttf': 11691},
#            'center': {'doc_freq': 120602,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 843,
#                                   'position': 126,
#                                   'start_offset': 837}],
#                       'ttf': 185410},
#            'chance': {'doc_freq': 60674,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 1606,
#                                   'position': 248,
#                                   'start_offset': 1600},
#                                  {'end_offset': 1733,
#                                   'position': 274,
#                                   'start_offset': 1727}],
#                       'ttf': 77383},
#            'climate': {'doc_freq': 9501,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 825,
#                                    'position': 124,
#                                    'start_offset': 818}],
#                        'ttf': 12327},
#            'coast': {'doc_freq': 29646,
#                      'term_freq': 2,
#                      'tokens': [{'end_offset': 1709,
#                                  'position': 269,
#                                  'start_offset': 1704},
#                                 {'end_offset': 1752,
#                                  'position': 278,
#                                  'start_offset': 1747}],
#                      'ttf': 45552},
#            'coasts': {'doc_freq': 1297,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 333,
#                                   'position': 49,
#                                   'start_offset': 327}],
#                       'ttf': 1543},
#            'colorado': {'doc_freq': 16017,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 1440,
#                                     'position': 222,
#                                     'start_offset': 1432}],
#                         'ttf': 26013},
#            'conditions': {'doc_freq': 38015,
#                           'term_freq': 2,
#                           'tokens': [{'end_offset': 1080,
#                                       'position': 167,
#                                       'start_offset': 1070},
#                                      {'end_offset': 1181,
#                                       'position': 180,
#                                       'start_offset': 1171}],
#                           'ttf': 46354},
#            'contribute': {'doc_freq': 13142,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 1105,
#                                       'position': 170,
#                                       'start_offset': 1095}],
#                           'ttf': 14026},
#            'cpc': {'doc_freq': 5360,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1129,
#                                'position': 174,
#                                'start_offset': 1126}],
#                    'ttf': 12422},
#            "don't": {'doc_freq': 167113,
#                      'term_freq': 2,
#                      'tokens': [{'end_offset': 660,
#                                  'position': 100,
#                                  'start_offset': 655},
#                                 {'end_offset': 929,
#                                  'position': 140,
#                                  'start_offset': 924}],
#                      'ttf': 283489},
#            'due': {'doc_freq': 57397,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1054,
#                                'position': 164,
#                                'start_offset': 1051}],
#                    'ttf': 63805},
#            'east': {'doc_freq': 94407,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 317,
#                                 'position': 46,
#                                 'start_offset': 313},
#                                {'end_offset': 1703,
#                                 'position': 268,
#                                 'start_offset': 1699}],
#                     'ttf': 149262},
#            'expected': {'doc_freq': 144353,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 1039,
#                                     'position': 160,
#                                     'start_offset': 1031}],
#                         'ttf': 188608},
#            'experiences': {'doc_freq': 8671,
#                            'term_freq': 1,
#                            'tokens': [{'end_offset': 502,
#                                        'position': 72,
#                                        'start_offset': 491}],
#                            'ttf': 9663},
#            'expert': {'doc_freq': 15610,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 1415,
#                                   'position': 218,
#                                   'start_offset': 1409}],
#                       'ttf': 17890},
#            'far': {'doc_freq': 132025,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1762,
#                                'position': 280,
#                                'start_offset': 1759}],
#                    'ttf': 163908},
#            'favor': {'doc_freq': 24553,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1353,
#                                  'position': 209,
#                                  'start_offset': 1348}],
#                      'ttf': 27045},
#            'figures': {'doc_freq': 38549,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1577,
#                                    'position': 242,
#                                    'start_offset': 1570}],
#                        'ttf': 46431},
#            'five': {'doc_freq': 193326,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 507,
#                                 'position': 73,
#                                 'start_offset': 503}],
#                     'ttf': 263538},
#            'fooled': {'doc_freq': 1189,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 47,
#                                   'position': 5,
#                                   'start_offset': 41},
#                                  {'end_offset': 671,
#                                   'position': 102,
#                                   'start_offset': 665}],
#                       'ttf': 1244},
#            'for': {'doc_freq': 876924,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1737,
#                                'position': 275,
#                                'start_offset': 1734}],
#                    'ttf': 4552259},
#            'four': {'doc_freq': 214409,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1544,
#                                 'position': 238,
#                                 'start_offset': 1540}],
#                     'ttf': 307884},
#            'from': {'doc_freq': 739183,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 884,
#                                 'position': 131,
#                                 'start_offset': 880},
#                                {'end_offset': 987,
#                                 'position': 151,
#                                 'start_offset': 983}],
#                     'ttf': 2117912},
#            'further': {'doc_freq': 78542,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1481,
#                                    'position': 229,
#                                    'start_offset': 1474}],
#                        'ttf': 89449},
#            'gerald': {'doc_freq': 5584,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 733,
#                                   'position': 113,
#                                   'start_offset': 727}],
#                       'ttf': 6187},
#            'get': {'doc_freq': 221333,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 664,
#                                'position': 101,
#                                'start_offset': 661}],
#                    'ttf': 381600},
#            'globally': {'doc_freq': 1694,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 1089,
#                                     'position': 168,
#                                     'start_offset': 1081}],
#                         'ttf': 1766},
#            'gone': {'doc_freq': 44635,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1466,
#                                 'position': 226,
#                                 'start_offset': 1462}],
#                     'ttf': 50838},
#            'government': {'doc_freq': 259507,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 105,
#                                       'position': 14,
#                                       'start_offset': 95}],
#                           'ttf': 520840},
#            'gray': {'doc_freq': 12931,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 1428,
#                                 'position': 220,
#                                 'start_offset': 1424},
#                                {'end_offset': 1569,
#                                 'position': 241,
#                                 'start_offset': 1565}],
#                     'ttf': 17783},
#            'gulf': {'doc_freq': 19419,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 326,
#                                 'position': 48,
#                                 'start_offset': 322},
#                                {'end_offset': 1746,
#                                 'position': 277,
#                                 'start_offset': 1742}],
#                     'ttf': 30766},
#            'has': {'doc_freq': 645815,
#                    'term_freq': 2,
#                    'tokens': [{'end_offset': 1461,
#                                'position': 225,
#                                'start_offset': 1458},
#                               {'end_offset': 1785,
#                                'position': 284,
#                                'start_offset': 1782}],
#                    'ttf': 1875144},
#            "haven't": {'doc_freq': 24300,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 622,
#                                    'position': 93,
#                                    'start_offset': 615}],
#                        'ttf': 27168},
#            'hit': {'doc_freq': 89904,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1694,
#                                'position': 266,
#                                'start_offset': 1691}],
#                    'ttf': 140394},
#            'hour': {'doc_freq': 57538,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1677,
#                                 'position': 262,
#                                 'start_offset': 1673}],
#                     'ttf': 74716},
#            'hurricane': {'doc_freq': 8497,
#                          'term_freq': 6,
#                          'tokens': [{'end_offset': 86,
#                                      'position': 12,
#                                      'start_offset': 77},
#                                     {'end_offset': 381,
#                                      'position': 55,
#                                      'start_offset': 372},
#                                     {'end_offset': 639,
#                                      'position': 96,
#                                      'start_offset': 630},
#                                     {'end_offset': 856,
#                                      'position': 127,
#                                      'start_offset': 847},
#                                     {'end_offset': 1408,
#                                      'position': 217,
#                                      'start_offset': 1399},
#                                     {'end_offset': 1914,
#                                      'position': 307,
#                                      'start_offset': 1905}],
#                          'ttf': 21718},
#            'hurricanes': {'doc_freq': 2710,
#                           'term_freq': 5,
#                           'tokens': [{'end_offset': 450,
#                                       'position': 64,
#                                       'start_offset': 440},
#                                      {'end_offset': 525,
#                                       'position': 76,
#                                       'start_offset': 515},
#                                      {'end_offset': 1119,
#                                       'position': 172,
#                                       'start_offset': 1109},
#                                      {'end_offset': 1535,
#                                       'position': 236,
#                                       'start_offset': 1525},
#                                      {'end_offset': 1563,
#                                       'position': 240,
#                                       'start_offset': 1553}],
#                           'ttf': 4639},
#            'in': {'doc_freq': 1012227,
#                   'term_freq': 3,
#                   'tokens': [{'end_offset': 454,
#                               'position': 65,
#                               'start_offset': 452},
#                              {'end_offset': 1343,
#                               'position': 207,
#                               'start_offset': 1341},
#                              {'end_offset': 1821,
#                               'position': 290,
#                               'start_offset': 1819}],
#                   'ttf': 9951757},
#            'including': {'doc_freq': 186188,
#                          'term_freq': 1,
#                          'tokens': [{'end_offset': 427,
#                                      'position': 61,
#                                      'start_offset': 418}],
#                          'ttf': 230202},
#            'intense': {'doc_freq': 14129,
#                        'term_freq': 3,
#                        'tokens': [{'end_offset': 251,
#                                    'position': 36,
#                                    'start_offset': 244},
#                                   {'end_offset': 1552,
#                                    'position': 239,
#                                    'start_offset': 1545},
#                                   {'end_offset': 1631,
#                                    'position': 253,
#                                    'start_offset': 1624}],
#                        'ttf': 15237},
#            'into': {'doc_freq': 352893,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 676,
#                                 'position': 103,
#                                 'start_offset': 672}],
#                     'ttf': 621575},
#            'is': {'doc_freq': 769647,
#                   'term_freq': 2,
#                   'tokens': [{'end_offset': 1030,
#                               'position': 159,
#                               'start_offset': 1028},
#                              {'end_offset': 1586,
#                               'position': 244,
#                               'start_offset': 1584}],
#                   'ttf': 3766994},
#            'june': {'doc_freq': 111551,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 889,
#                                 'position': 132,
#                                 'start_offset': 885},
#                                {'end_offset': 1826,
#                                 'position': 291,
#                                 'start_offset': 1822}],
#                     'ttf': 151286},
#            'just': {'doc_freq': 264197,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 603,
#                                 'position': 90,
#                                 'start_offset': 599}],
#                     'ttf': 485984},
#            'kousky': {'doc_freq': 5,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 1157,
#                                   'position': 177,
#                                   'start_offset': 1151},
#                                  {'end_offset': 1395,
#                                   'position': 216,
#                                   'start_offset': 1389}],
#                       'ttf': 10},
#            'landfall': {'doc_freq': 533,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 593,
#                                     'position': 89,
#                                     'start_offset': 585}],
#                         'ttf': 675},
#            'last': {'doc_freq': 410984,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 364,
#                                 'position': 53,
#                                 'start_offset': 360}],
#                     'ttf': 741747},
#            'light': {'doc_freq': 44353,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 711,
#                                  'position': 110,
#                                  'start_offset': 706}],
#                      'ttf': 58684},
#            'living': {'doc_freq': 53761,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 302,
#                                   'position': 43,
#                                   'start_offset': 296}],
#                       'ttf': 67964},
#            'low': {'doc_freq': 71971,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1191,
#                                'position': 183,
#                                'start_offset': 1188}],
#                    'ttf': 95529},
#            'major': {'doc_freq': 171788,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 439,
#                                  'position': 63,
#                                  'start_offset': 434}],
#                      'ttf': 222927},
#            'make': {'doc_freq': 241250,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 584,
#                                 'position': 88,
#                                 'start_offset': 580}],
#                     'ttf': 357009},
#            'meteorologist': {'doc_freq': 997,
#                              'term_freq': 2,
#                              'tokens': [{'end_offset': 764,
#                                          'position': 117,
#                                          'start_offset': 751},
#                                         {'end_offset': 1143,
#                                          'position': 175,
#                                          'start_offset': 1130}],
#                              'ttf': 1142},
#            'meteorologists': {'doc_freq': 862,
#                               'term_freq': 1,
#                               'tokens': [{'end_offset': 173,
#                                           'position': 24,
#                                           'start_offset': 159}],
#                               'ttf': 1059},
#            'mid': {'doc_freq': 33049,
#                    'term_freq': 3,
#                    'tokens': [{'end_offset': 953,
#                                'position': 145,
#                                'start_offset': 950},
#                               {'end_offset': 991,
#                                'position': 152,
#                                'start_offset': 988},
#                               {'end_offset': 1005,
#                                'position': 155,
#                                'start_offset': 1002}],
#                    'ttf': 37298},
#            'miles': {'doc_freq': 52942,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1668,
#                                  'position': 260,
#                                  'start_offset': 1663}],
#                      'ttf': 76426},
#            'more': {'doc_freq': 475463,
#                     'term_freq': 5,
#                     'tokens': [{'end_offset': 193,
#                                 'position': 27,
#                                 'start_offset': 189},
#                                {'end_offset': 243,
#                                 'position': 35,
#                                 'start_offset': 239},
#                                {'end_offset': 1361,
#                                 'position': 211,
#                                 'start_offset': 1357},
#                                {'end_offset': 1623,
#                                 'position': 252,
#                                 'start_offset': 1619},
#                                {'end_offset': 1685,
#                                 'position': 264,
#                                 'start_offset': 1681}],
#                     'ttf': 1056472},
#            'mph': {'doc_freq': 7470,
#                    'term_freq': 2,
#                    'tokens': [{'end_offset': 1876,
#                                'position': 301,
#                                'start_offset': 1873},
#                               {'end_offset': 1948,
#                                'position': 313,
#                                'start_offset': 1945}],
#                    'ttf': 15774},
#            'named': {'doc_freq': 45590,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1502,
#                                  'position': 232,
#                                  'start_offset': 1497}],
#                      'ttf': 54147},
#            'national': {'doc_freq': 244618,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 776,
#                                     'position': 119,
#                                     'start_offset': 768}],
#                         'ttf': 381395},
#            'nine': {'doc_freq': 65882,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1524,
#                                 'position': 235,
#                                 'start_offset': 1520}],
#                     'ttf': 78708},
#            'normal': {'doc_freq': 25109,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 1380,
#                                   'position': 214,
#                                   'start_offset': 1374}],
#                       'ttf': 30741},
#            'nov': {'doc_freq': 18648,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 898,
#                                'position': 135,
#                                'start_offset': 895}],
#                    'ttf': 32207},
#            'ocean': {'doc_freq': 13344,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1297,
#                                  'position': 199,
#                                  'start_offset': 1292}],
#                      'ttf': 19276},
#            'oceanic': {'doc_freq': 954,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 784,
#                                    'position': 120,
#                                    'start_offset': 777}],
#                        'ttf': 1278},
#            'october': {'doc_freq': 75140,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1013,
#                                    'position': 156,
#                                    'start_offset': 1006}],
#                        'ttf': 88359},
#            'odds': {'doc_freq': 9794,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1329,
#                                 'position': 204,
#                                 'start_offset': 1325}],
#                     'ttf': 11211},
#            'of': {'doc_freq': 1030861,
#                   'term_freq': 6,
#                   'tokens': [{'end_offset': 533,
#                               'position': 78,
#                               'start_offset': 531},
#                              {'end_offset': 568,
#                               'position': 85,
#                               'start_offset': 566},
#                              {'end_offset': 1356,
#                               'position': 210,
#                               'start_offset': 1354},
#                              {'end_offset': 1431,
#                               'position': 221,
#                               'start_offset': 1429},
#                              {'end_offset': 1658,
#                               'position': 258,
#                               'start_offset': 1656},
#                              {'end_offset': 1863,
#                               'position': 297,
#                               'start_offset': 1861}],
#                   'ttf': 12432829},
#            'officially': {'doc_freq': 14369,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 874,
#                                       'position': 129,
#                                       'start_offset': 864}],
#                           'ttf': 15021},
#            'one': {'doc_freq': 482436,
#                    'term_freq': 2,
#                    'tokens': [{'end_offset': 1615,
#                                'position': 250,
#                                'start_offset': 1612},
#                               {'end_offset': 1794,
#                                'position': 286,
#                                'start_offset': 1791}],
#                    'ttf': 1102844},
#            'or': {'doc_freq': 439301,
#                   'term_freq': 3,
#                   'tokens': [{'end_offset': 238,
#                               'position': 34,
#                               'start_offset': 236},
#                              {'end_offset': 1618,
#                               'position': 251,
#                               'start_offset': 1616},
#                              {'end_offset': 1680,
#                               'position': 263,
#                               'start_offset': 1678}],
#                   'ttf': 1147071},
#            'peak': {'doc_freq': 10033,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 135,
#                                 'position': 19,
#                                 'start_offset': 131},
#                                {'end_offset': 970,
#                                 'position': 148,
#                                 'start_offset': 966}],
#                     'ttf': 12006},
#            'people': {'doc_freq': 341498,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 27,
#                                   'position': 2,
#                                   'start_offset': 21}],
#                       'ttf': 723376},
#            'per': {'doc_freq': 55812,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 1672,
#                                'position': 261,
#                                'start_offset': 1669}],
#                    'ttf': 91283},
#            'percent': {'doc_freq': 233267,
#                        'term_freq': 2,
#                        'tokens': [{'end_offset': 1599,
#                                    'position': 247,
#                                    'start_offset': 1592},
#                                   {'end_offset': 1726,
#                                    'position': 273,
#                                    'start_offset': 1719}],
#                        'ttf': 711938},
#            'period': {'doc_freq': 67850,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 142,
#                                   'position': 20,
#                                   'start_offset': 136},
#                                  {'end_offset': 977,
#                                   'position': 149,
#                                   'start_offset': 971}],
#                       'ttf': 94385},
#            'possible': {'doc_freq': 86342,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 280,
#                                     'position': 40,
#                                     'start_offset': 272}],
#                         'ttf': 100432},
#            'predicting': {'doc_freq': 3954,
#                           'term_freq': 2,
#                           'tokens': [{'end_offset': 188,
#                                       'position': 26,
#                                       'start_offset': 178},
#                                      {'end_offset': 1493,
#                                       'position': 230,
#                                       'start_offset': 1483}],
#                           'ttf': 4141},
#            'prediction': {'doc_freq': 2770,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 836,
#                                       'position': 125,
#                                       'start_offset': 826}],
#                           'ttf': 3400},
#            'prepared': {'doc_freq': 31252,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 356,
#                                     'position': 52,
#                                     'start_offset': 348}],
#                         'ttf': 34857},
#            'pressure': {'doc_freq': 50918,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 1262,
#                                     'position': 194,
#                                     'start_offset': 1254}],
#                         'ttf': 63986},
#            'produced': {'doc_freq': 31837,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 397,
#                                     'position': 57,
#                                     'start_offset': 389}],
#                         'ttf': 36549},
#            'reach': {'doc_freq': 60431,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1941,
#                                  'position': 311,
#                                  'start_offset': 1936}],
#                      'ttf': 67598},
#            'really': {'doc_freq': 97685,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 936,
#                                   'position': 141,
#                                   'start_offset': 930}],
#                       'ttf': 137920},
#            'remain': {'doc_freq': 51469,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 347,
#                                   'position': 51,
#                                   'start_offset': 341}],
#                       'ttf': 57134},
#            'research': {'doc_freq': 62143,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 750,
#                                     'position': 116,
#                                     'start_offset': 742}],
#                         'ttf': 100319},
#            'residents': {'doc_freq': 36518,
#                          'term_freq': 1,
#                          'tokens': [{'end_offset': 295,
#                                      'position': 42,
#                                      'start_offset': 286}],
#                          'ttf': 54716},
#            'rev': {'doc_freq': 9182,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 940,
#                                'position': 142,
#                                'start_offset': 937}],
#                    'ttf': 12389},
#            'runs': {'doc_freq': 39637,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 879,
#                                 'position': 130,
#                                 'start_offset': 875},
#                                {'end_offset': 982,
#                                 'position': 150,
#                                 'start_offset': 978}],
#                     'ttf': 64215},
#            'said': {'doc_freq': 738550,
#                     'term_freq': 3,
#                     'tokens': [{'end_offset': 726,
#                                 'position': 112,
#                                 'start_offset': 722},
#                                {'end_offset': 1125,
#                                 'position': 173,
#                                 'start_offset': 1121},
#                                {'end_offset': 1388,
#                                 'position': 215,
#                                 'start_offset': 1384}],
#                     'ttf': 3595518},
#            'say': {'doc_freq': 183938,
#                    'term_freq': 2,
#                    'tokens': [{'end_offset': 120,
# ...
#                       'tokens': [{'end_offset': 200,
#                                   'position': 28,
#                                   'start_offset': 194},
#                                  {'end_offset': 267,
#                                   'position': 38,
#                                   'start_offset': 261},
#                                  {'end_offset': 416,
#                                   'position': 60,
#                                   'start_offset': 410},
#                                  {'end_offset': 579,
#                                   'position': 87,
#                                   'start_offset': 573},
#                                  {'end_offset': 923,
#                                   'position': 139,
#                                   'start_offset': 917},
#                                  {'end_offset': 1368,
#                                   'position': 212,
#                                   'start_offset': 1362},
#                                  {'end_offset': 1518,
#                                   'position': 234,
#                                   'start_offset': 1512},
#                                  {'end_offset': 1638,
#                                   'position': 254,
#                                   'start_offset': 1632}],
#                       'ttf': 6352},
#            'sustained': {'doc_freq': 10379,
#                          'term_freq': 1,
#                          'tokens': [{'end_offset': 1929,
#                                      'position': 309,
#                                      'start_offset': 1920}],
#                          'ttf': 11132},
#            'than': {'doc_freq': 403359,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 205,
#                                 'position': 29,
#                                 'start_offset': 201},
#                                {'end_offset': 1373,
#                                 'position': 213,
#                                 'start_offset': 1369}],
#                     'ttf': 761261},
#            'that': {'doc_freq': 801723,
#                     'term_freq': 3,
#                     'tokens': [{'end_offset': 690,
#                                 'position': 105,
#                                 'start_offset': 686},
#                                {'end_offset': 1094,
#                                 'position': 169,
#                                 'start_offset': 1090},
#                                {'end_offset': 1611,
#                                 'position': 249,
#                                 'start_offset': 1607}],
#                     'ttf': 4645728},
#            'the': {'doc_freq': 1071226,
#                    'term_freq': 11,
#                    'tokens': [{'end_offset': 130,
#                                'position': 18,
#                                'start_offset': 127},
#                               {'end_offset': 312,
#                                'position': 45,
#                                'start_offset': 309},
#                               {'end_offset': 476,
#                                'position': 69,
#                                'start_offset': 473},
#                               {'end_offset': 965,
#                                'position': 147,
#                                'start_offset': 962},
#                               {'end_offset': 1020,
#                                'position': 157,
#                                'start_offset': 1017},
#                               {'end_offset': 1213,
#                                'position': 187,
#                                'start_offset': 1210},
#                               {'end_offset': 1273,
#                                'position': 196,
#                                'start_offset': 1270},
#                               {'end_offset': 1324,
#                                'position': 203,
#                                'start_offset': 1321},
#                               {'end_offset': 1347,
#                                'position': 208,
#                                'start_offset': 1344},
#                               {'end_offset': 1698,
#                                'position': 267,
#                                'start_offset': 1695},
#                               {'end_offset': 1741,
#                                'position': 276,
#                                'start_offset': 1738}],
#                    'ttf': 29385626},
#            'there': {'doc_freq': 350381,
#                      'term_freq': 2,
#                      'tokens': [{'end_offset': 1583,
#                                  'position': 243,
#                                  'start_offset': 1578},
#                                 {'end_offset': 1781,
#                                  'position': 283,
#                                  'start_offset': 1776}],
#                      'ttf': 701944},
#            'thinking': {'doc_freq': 28267,
#                         'term_freq': 1,
#                         'tokens': [{'end_offset': 685,
#                                     'position': 104,
#                                     'start_offset': 677}],
#                         'ttf': 32586},
#            'this': {'doc_freq': 571129,
#                     'term_freq': 4,
#                     'tokens': [{'end_offset': 55,
#                                 'position': 7,
#                                 'start_offset': 51},
#                                {'end_offset': 648,
#                                 'position': 98,
#                                 'start_offset': 644},
#                                {'end_offset': 695,
#                                 'position': 106,
#                                 'start_offset': 691},
#                                {'end_offset': 1767,
#                                 'position': 281,
#                                 'start_offset': 1763}],
#                     'ttf': 1465690},
#            'those': {'doc_freq': 218445,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 1170,
#                                  'position': 179,
#                                  'start_offset': 1165}],
#                      'ttf': 328110},
#            'three': {'doc_freq': 320794,
#                      'term_freq': 2,
#                      'tokens': [{'end_offset': 235,
#                                  'position': 33,
#                                  'start_offset': 230},
#                                 {'end_offset': 433,
#                                  'position': 62,
#                                  'start_offset': 428}],
#                      'ttf': 513945},
#            'tilted': {'doc_freq': 854,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 1340,
#                                   'position': 206,
#                                   'start_offset': 1334}],
#                       'ttf': 877},
#            'to': {'doc_freq': 1004067,
#                   'term_freq': 9,
#                   'tokens': [{'end_offset': 76,
#                               'position': 11,
#                               'start_offset': 74},
#                              {'end_offset': 151,
#                               'position': 22,
#                               'start_offset': 149},
#                              {'end_offset': 510,
#                               'position': 74,
#                               'start_offset': 508},
#                              {'end_offset': 894,
#                               'position': 134,
#                               'start_offset': 892},
#                              {'end_offset': 1001,
#                               'position': 154,
#                               'start_offset': 999},
#                              {'end_offset': 1042,
#                               'position': 161,
#                               'start_offset': 1040},
#                              {'end_offset': 1057,
#                               'position': 165,
#                               'start_offset': 1055},
#                              {'end_offset': 1108,
#                               'position': 171,
#                               'start_offset': 1106},
#                              {'end_offset': 1869,
#                               'position': 299,
#                               'start_offset': 1867}],
#                   'ttf': 12029083},
#            'tropical': {'doc_freq': 5590,
#                         'term_freq': 8,
#                         'tokens': [{'end_offset': 409,
#                                     'position': 59,
#                                     'start_offset': 401},
#                                    {'end_offset': 916,
#                                     'position': 138,
#                                     'start_offset': 908},
#                                    {'end_offset': 1222,
#                                     'position': 188,
#                                     'start_offset': 1214},
#                                    {'end_offset': 1282,
#                                     'position': 197,
#                                     'start_offset': 1274},
#                                    {'end_offset': 1511,
#                                     'position': 233,
#                                     'start_offset': 1503},
#                                    {'end_offset': 1803,
#                                     'position': 287,
#                                     'start_offset': 1795},
#                                    {'end_offset': 1840,
#                                     'position': 293,
#                                     'start_offset': 1832},
#                                    {'end_offset': 1888,
#                                     'position': 303,
#                                     'start_offset': 1880}],
#                         'ttf': 7988},
#            'two': {'doc_freq': 478414,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 530,
#                                'position': 77,
#                                'start_offset': 527}],
#                    'ttf': 938168},
#            'typical': {'doc_freq': 12846,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 464,
#                                    'position': 67,
#                                    'start_offset': 457}],
#                        'ttf': 14017},
#            'united': {'doc_freq': 205949,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 483,
#                                   'position': 70,
#                                   'start_offset': 477}],
#                       'ttf': 381528},
#            'university': {'doc_freq': 86783,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 1457,
#                                       'position': 224,
#                                       'start_offset': 1447}],
#                           'ttf': 146093},
#            'until': {'doc_freq': 133710,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 949,
#                                  'position': 144,
#                                  'start_offset': 944}],
#                      'ttf': 178922},
#            'up': {'doc_freq': 454138,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 943,
#                               'position': 143,
#                               'start_offset': 941}],
#                   'ttf': 918281},
#            'usual': {'doc_freq': 16585,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 211,
#                                  'position': 30,
#                                  'start_offset': 206}],
#                      'ttf': 17904},
#            'vernon': {'doc_freq': 3194,
#                       'term_freq': 1,
#                       'tokens': [{'end_offset': 1150,
#                                   'position': 176,
#                                   'start_offset': 1144}],
#                       'ttf': 4323},
#            'washington': {'doc_freq': 166055,
#                           'term_freq': 1,
#                           'tokens': [{'end_offset': 12,
#                                       'position': 0,
#                                       'start_offset': 2}],
#                           'ttf': 291092},
#            'we': {'doc_freq': 327457,
#                   'term_freq': 1,
#                   'tokens': [{'end_offset': 614,
#                               'position': 92,
#                               'start_offset': 612}],
#                   'ttf': 921687},
#            'when': {'doc_freq': 404848,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 1919,
#                                 'position': 308,
#                                 'start_offset': 1915}],
#                     'ttf': 876467},
#            'which': {'doc_freq': 514828,
#                      'term_freq': 1,
#                      'tokens': [{'end_offset': 539,
#                                  'position': 79,
#                                  'start_offset': 534}],
#                      'ttf': 976104},
#            'will': {'doc_freq': 577557,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 700,
#                                 'position': 107,
#                                 'start_offset': 696},
#                                {'end_offset': 1690,
#                                 'position': 265,
#                                 'start_offset': 1686}],
#                     'ttf': 1552428},
#            'william': {'doc_freq': 40370,
#                        'term_freq': 1,
#                        'tokens': [{'end_offset': 1423,
#                                    'position': 219,
#                                    'start_offset': 1416}],
#                        'ttf': 48182},
#            'wind': {'doc_freq': 16162,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 1196,
#                                 'position': 184,
#                                 'start_offset': 1192},
#                                {'end_offset': 1648,
#                                 'position': 256,
#                                 'start_offset': 1644}],
#                     'ttf': 26880},
#            'winds': {'doc_freq': 9695,
#                      'term_freq': 2,
#                      'tokens': [{'end_offset': 1860,
#                                  'position': 296,
#                                  'start_offset': 1855},
#                                 {'end_offset': 1935,
#                                  'position': 310,
#                                  'start_offset': 1930}],
#                      'ttf': 15216},
#            'with': {'doc_freq': 788781,
#                     'term_freq': 2,
#                     'tokens': [{'end_offset': 126,
#                                 'position': 17,
#                                 'start_offset': 122},
#                                {'end_offset': 1643,
#                                 'position': 255,
#                                 'start_offset': 1639}],
#                     'ttf': 3115054},
#            'year': {'doc_freq': 468541,
#                     'term_freq': 1,
#                     'tokens': [{'end_offset': 653,
#                                 'position': 99,
#                                 'start_offset': 649}],
#                     'ttf': 1011333},
#            "year's": {'doc_freq': 50186,
#                       'term_freq': 2,
#                       'tokens': [{'end_offset': 62,
#                                   'position': 8,
#                                   'start_offset': 56},
#                                  {'end_offset': 371,
#                                   'position': 54,
#                                   'start_offset': 365}],
#                       'ttf': 62369},
#            'yet': {'doc_freq': 97410,
#                    'term_freq': 1,
#                    'tokens': [{'end_offset': 643,
#                                'position': 97,
#                                'start_offset': 640}],
#                    'ttf': 120568}}}
# 467.25727144033493

# %%
print(new_score)
# Out:
# 2
